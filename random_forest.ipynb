# %%
import numpy as np               
import matplotlib.pyplot as plt  
import pandas as pd
from sklearn import tree, ensemble, datasets
import scipy as sc

# %%
print(np.__version__,"np")
#print(plt.__version__,"plt")
print(pd.__version__,"pd")
print(sc.__version__,"sc")
# Out:
# 1.20.1 np
# 1.2.4 pd
# 1.6.2 sc

# %%
#https://hydrocoast.jp/index.php?Python/mat%E5%BD%A2%E5%BC%8F%E3%83%95%E3%82%A1%E3%82%A4%E3%83%AB%E3%81%8B%E3%82%89%E3%81%AE%E5%A4%89%E6%95%B0%E8%AA%AD%E3%81%BF%E8%BE%BC%E3%81%BF
import scipy.io

dic = scipy.io.loadmat('/Users/ShuntaroMiwa/00 python/iiyama/imdb_crop/imdb.mat')
print(dic.items())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-07a247e1090d> in <module>
#       3
#       4 dic = scipy.io.loadmat('/Users/ShuntaroMiwa/00 python/iiyama/imdb_crop/imdb.mat')
# ----> 5 dic.imdb[0][0][1][0]
#
# AttributeError: 'dict' object has no attribute 'imdb'

# %%
#https://github.com/imdeepmind/processed-imdb-wiki-dataset#file-structure

import numpy as np
from scipy.io import loadmat
import pandas as pd
import datetime as date
from dateutil.relativedelta import relativedelta

cols = ['age', 'gender', 'path', 'face_score1', 'face_score2']

imdb_mat = '/Users/ShuntaroMiwa/00 python/iiyama/imdb_crop/imdb.mat'
wiki_mat = '/Users/ShuntaroMiwa/00 python/iiyama/wiki_crop/wiki.mat'

imdb_data = loadmat(imdb_mat)
wiki_data = loadmat(wiki_mat)

del imdb_mat, wiki_mat

imdb = imdb_data['imdb']
wiki = wiki_data['wiki']

imdb_photo_taken = imdb[0][0][1][0]
imdb_full_path = imdb[0][0][2][0]
imdb_gender = imdb[0][0][3][0]
imdb_face_score1 = imdb[0][0][6][0]
imdb_face_score2 = imdb[0][0][7][0]

wiki_photo_taken = wiki[0][0][1][0]
wiki_full_path = wiki[0][0][2][0]
wiki_gender = wiki[0][0][3][0]
wiki_face_score1 = wiki[0][0][6][0]
wiki_face_score2 = wiki[0][0][7][0]

imdb_path = []
wiki_path = []

for path in imdb_full_path:
    imdb_path.append('imdb_crop/' + path[0])

for path in wiki_full_path:
    wiki_path.append('wiki_crop/' + path[0])

imdb_genders = []
wiki_genders = []

for n in range(len(imdb_gender)):
    if imdb_gender[n] == 1:
        imdb_genders.append('male')
    else:
        imdb_genders.append('female')

for n in range(len(wiki_gender)):
    if wiki_gender[n] == 1:
        wiki_genders.append('male')
    else:
        wiki_genders.append('female')

imdb_dob = []
wiki_dob = []

for file in imdb_path:
    temp = file.split('_')[3]
    temp = temp.split('-')
    if len(temp[1]) == 1:
        temp[1] = '0' + temp[1]
    if len(temp[2]) == 1:
        temp[2] = '0' + temp[2]

    if temp[1] == '00':
        temp[1] = '01'
    if temp[2] == '00':
        temp[2] = '01'
    
    imdb_dob.append('-'.join(temp))

for file in wiki_path:
    wiki_dob.append(file.split('_')[2])

# %%
print(imdb_photo_taken[4600])

# import collections
# c = collections.Counter(imdb_dob)

# print(c.most_common())

# #print(imdb_dob[460000])
# Out:
# 2005

# %%
#print(len(imdb_dob))

imdb_dob = ["2000-12-22" if i == "0-12-22" else i for i in imdb_dob]
imdb_dob = ["2000-05-21" if i == "0-05-21" else i for i in imdb_dob]
imdb_dob = ["2000-11-18" if i == "0-11-18" else i for i in imdb_dob]
imdb_dob = ["2000-07-31" if i == "0-07-31" else i for i in imdb_dob]
imdb_dob = ["2000-10-20" if i == "0-10-20" else i for i in imdb_dob]
imdb_dob = ["2000-08-19" if i == "0-08-19" else i for i in imdb_dob]
imdb_dob = ["2000-08-07" if i == "0-08-07" else i for i in imdb_dob]
imdb_dob = ["2000-09-08" if i == "0-09-08" else i for i in imdb_dob]
imdb_dob = ["2000-11-19" if i == "0-11-19" else i for i in imdb_dob]
imdb_dob = ["2000-08-05" if i == "0-08-05" else i for i in imdb_dob]
imdb_dob = ["2000-08-27" if i == "0-08-27" else i for i in imdb_dob]
imdb_dob = ["2000-07-08" if i == "0-07-08" else i for i in imdb_dob]
imdb_dob = ["2000-05-05" if i == "0-05-05" else i for i in imdb_dob]
imdb_dob = ["2000-03-15" if i == "0-03-15" else i for i in imdb_dob]
imdb_dob = ["2000-12-29" if i == "0-12-29" else i for i in imdb_dob]
imdb_dob = ["2000-08-21" if i == "0-08-21" else i for i in imdb_dob]
imdb_dob = ["2000-02-16" if i == "0-02-16" else i for i in imdb_dob]
imdb_dob = ["2000-12-10" if i == "0-12-10" else i for i in imdb_dob]
imdb_dob = ["2000-10-17" if i == "0-10-17" else i for i in imdb_dob]
imdb_dob = ["2000-08-08" if i == "0-08-08" else i for i in imdb_dob]
imdb_dob = ["2000-09-02" if i == "0-09-02" else i for i in imdb_dob]
imdb_dob = ["2000-12-28" if i == "0-12-28" else i for i in imdb_dob]
imdb_dob = ["2000-02-22" if i == "0-02-22" else i for i in imdb_dob]
imdb_dob = ["2000-09-05" if i == "0-09-05" else i for i in imdb_dob]
imdb_dob = ["2000-07-10" if i == "0-07-10" else i for i in imdb_dob]
imdb_dob = ["2000-06-23" if i == "0-06-23" else i for i in imdb_dob]
imdb_dob = ["2000-12-10" if i == "0-12-10" else i for i in imdb_dob]
imdb_dob = ["2000-12-17" if i == "0-12-17" else i for i in imdb_dob]
imdb_dob = ["2000-09-20" if i == "0-09-20" else i for i in imdb_dob]
imdb_dob = ["2000-11-29" if i == "0-11-29" else i for i in imdb_dob]
imdb_dob = ["2000-12-17" if i == "0-12-17" else i for i in imdb_dob]
imdb_dob = ["2000-04-12" if i == "0-04-12" else i for i in imdb_dob]
imdb_dob = ["2000-07-22" if i == "0-07-22" else i for i in imdb_dob]
imdb_dob = ["2000-07-10" if i == "0-07-10" else i for i in imdb_dob]
imdb_dob = ["2000-11-06" if i == "0-11-06" else i for i in imdb_dob]
imdb_dob = ["2000-10-02" if i == "0-10-02" else i for i in imdb_dob]
imdb_dob = ["2000-09-09" if i == "0-09-09" else i for i in imdb_dob]
imdb_dob = ["2000-09-07" if i == "0-09-07" else i for i in imdb_dob]
imdb_dob = ["2000-11-13" if i == "0-11-13" else i for i in imdb_dob]
imdb_dob = ["2000-07-27" if i == "0-07-27" else i for i in imdb_dob]
imdb_dob = ["1829-09-08" if i == "829-09-08" else i for i in imdb_dob]
imdb_dob = ["1953-10-01" if i == "1953-10-00" else i for i in imdb_dob]
imdb_dob = ["1984-12-03" if i == "1984-15-03" else i for i in imdb_dob]
imdb_dob = ["1963-02-01" if i == "1963-02-00" else i for i in imdb_dob]
imdb_dob = ["1977-04-01" if i == "1977-04-00" else i for i in imdb_dob]
imdb_dob = ["1946-05-01" if i == "1946-05-00" else i for i in imdb_dob]
imdb_dob = ["1647-05-15" if i == "647-05-15" else i for i in imdb_dob]
imdb_dob = ["2011-03-01" if i == "11-03-00" else i for i in imdb_dob]
imdb_dob = ["1980-05-01" if i == "1980-05-00" else i for i in imdb_dob]
imdb_dob = ["1960-02-01" if i == "1960-02-00" else i for i in imdb_dob]
imdb_dob = ["1975-03-01" if i == "1975-03-00" else i for i in imdb_dob]
imdb_dob = ["1952-11-01" if i == "1952-11-00" else i for i in imdb_dob]
imdb_dob = ["1974-04-01" if i == "1974-04-00" else i for i in imdb_dob]
imdb_dob = ["1996-05-25" if i == "1996-25-05" else i for i in imdb_dob]
wiki_dob = ["2000-12-22" if i == "0-12-22" else i for i in wiki_dob]
wiki_dob = ["2000-05-21" if i == "0-05-21" else i for i in wiki_dob]
wiki_dob = ["2000-11-18" if i == "0-11-18" else i for i in wiki_dob]
wiki_dob = ["2000-07-31" if i == "0-07-31" else i for i in wiki_dob]
wiki_dob = ["2000-10-20" if i == "0-10-20" else i for i in wiki_dob]
wiki_dob = ["2000-08-19" if i == "0-08-19" else i for i in wiki_dob]
wiki_dob = ["2000-08-07" if i == "0-08-07" else i for i in wiki_dob]
wiki_dob = ["2000-09-08" if i == "0-09-08" else i for i in wiki_dob]
wiki_dob = ["2000-11-19" if i == "0-11-19" else i for i in wiki_dob]
wiki_dob = ["2000-08-05" if i == "0-08-05" else i for i in wiki_dob]
wiki_dob = ["2000-08-27" if i == "0-08-27" else i for i in wiki_dob]
wiki_dob = ["2000-07-08" if i == "0-07-08" else i for i in wiki_dob]
wiki_dob = ["2000-05-05" if i == "0-05-05" else i for i in wiki_dob]
wiki_dob = ["2000-03-15" if i == "0-03-15" else i for i in wiki_dob]
wiki_dob = ["2000-12-29" if i == "0-12-29" else i for i in wiki_dob]
wiki_dob = ["2000-08-21" if i == "0-08-21" else i for i in wiki_dob]
wiki_dob = ["2000-02-16" if i == "0-02-16" else i for i in wiki_dob]
wiki_dob = ["2000-12-10" if i == "0-12-10" else i for i in wiki_dob]
wiki_dob = ["2000-10-17" if i == "0-10-17" else i for i in wiki_dob]
wiki_dob = ["2000-08-08" if i == "0-08-08" else i for i in wiki_dob]
wiki_dob = ["2000-09-02" if i == "0-09-02" else i for i in wiki_dob]
wiki_dob = ["2000-12-28" if i == "0-12-28" else i for i in wiki_dob]
wiki_dob = ["2000-02-22" if i == "0-02-22" else i for i in wiki_dob]
wiki_dob = ["2000-09-05" if i == "0-09-05" else i for i in wiki_dob]
wiki_dob = ["2000-07-10" if i == "0-07-10" else i for i in wiki_dob]
wiki_dob = ["2000-06-23" if i == "0-06-23" else i for i in wiki_dob]
wiki_dob = ["2000-12-10" if i == "0-12-10" else i for i in wiki_dob]
wiki_dob = ["2000-12-17" if i == "0-12-17" else i for i in wiki_dob]
wiki_dob = ["2000-09-20" if i == "0-09-20" else i for i in wiki_dob]
wiki_dob = ["2000-11-29" if i == "0-11-29" else i for i in wiki_dob]
wiki_dob = ["2000-12-17" if i == "0-12-17" else i for i in wiki_dob]
wiki_dob = ["2000-04-12" if i == "0-04-12" else i for i in wiki_dob]
wiki_dob = ["2000-07-22" if i == "0-07-22" else i for i in wiki_dob]
wiki_dob = ["2000-07-10" if i == "0-07-10" else i for i in wiki_dob]
wiki_dob = ["2000-11-06" if i == "0-11-06" else i for i in wiki_dob]
wiki_dob = ["2000-10-02" if i == "0-10-02" else i for i in wiki_dob]
wiki_dob = ["2000-09-09" if i == "0-09-09" else i for i in wiki_dob]
wiki_dob = ["2000-09-07" if i == "0-09-07" else i for i in wiki_dob]
wiki_dob = ["2000-11-13" if i == "0-11-13" else i for i in wiki_dob]
wiki_dob = ["2000-07-27" if i == "0-07-27" else i for i in wiki_dob]
wiki_dob = ["1829-09-08" if i == "829-09-08" else i for i in wiki_dob]
wiki_dob = ["1953-10-01" if i == "1953-10-00" else i for i in wiki_dob]
wiki_dob = ["1984-12-03" if i == "1984-15-03" else i for i in wiki_dob]
wiki_dob = ["1963-02-01" if i == "1963-02-00" else i for i in wiki_dob]
wiki_dob = ["1977-04-01" if i == "1977-04-00" else i for i in wiki_dob]
wiki_dob = ["1946-05-01" if i == "1946-05-00" else i for i in wiki_dob]
wiki_dob = ["1647-05-15" if i == "647-05-15" else i for i in wiki_dob]
wiki_dob = ["2011-03-01" if i == "11-03-00" else i for i in wiki_dob]
wiki_dob = ["1980-05-01" if i == "1980-05-00" else i for i in wiki_dob]
wiki_dob = ["1960-02-01" if i == "1960-02-00" else i for i in wiki_dob]
wiki_dob = ["1975-03-01" if i == "1975-03-00" else i for i in wiki_dob]
wiki_dob = ["1952-11-01" if i == "1952-11-00" else i for i in wiki_dob]
wiki_dob = ["1974-04-01" if i == "1974-04-00" else i for i in wiki_dob]
wiki_dob = ["1996-05-25" if i == "1996-25-05" else i for i in wiki_dob]

imdb_dob = ["2000-12-22" if i == "00-12-22" else i for i in imdb_dob]
imdb_dob = ["2000-05-21" if i == "00-05-21" else i for i in imdb_dob]
imdb_dob = ["2000-11-18" if i == "00-11-18" else i for i in imdb_dob]
imdb_dob = ["2000-07-31" if i == "00-07-31" else i for i in imdb_dob]
imdb_dob = ["2000-10-20" if i == "00-10-20" else i for i in imdb_dob]
imdb_dob = ["2000-08-19" if i == "00-08-19" else i for i in imdb_dob]
imdb_dob = ["2000-08-07" if i == "00-08-07" else i for i in imdb_dob]
imdb_dob = ["2000-09-08" if i == "00-09-08" else i for i in imdb_dob]
imdb_dob = ["2000-11-19" if i == "00-11-19" else i for i in imdb_dob]
imdb_dob = ["2000-08-05" if i == "00-08-05" else i for i in imdb_dob]
imdb_dob = ["2000-08-27" if i == "00-08-27" else i for i in imdb_dob]
imdb_dob = ["2000-07-08" if i == "00-07-08" else i for i in imdb_dob]
imdb_dob = ["2000-05-05" if i == "00-05-05" else i for i in imdb_dob]
imdb_dob = ["2000-03-15" if i == "00-03-15" else i for i in imdb_dob]
imdb_dob = ["2000-12-29" if i == "00-12-29" else i for i in imdb_dob]
imdb_dob = ["2000-08-21" if i == "00-08-21" else i for i in imdb_dob]
imdb_dob = ["2000-02-16" if i == "00-02-16" else i for i in imdb_dob]
imdb_dob = ["2000-12-10" if i == "00-12-10" else i for i in imdb_dob]
imdb_dob = ["2000-10-17" if i == "00-10-17" else i for i in imdb_dob]
imdb_dob = ["2000-08-08" if i == "00-08-08" else i for i in imdb_dob]
imdb_dob = ["2000-09-02" if i == "00-09-02" else i for i in imdb_dob]
imdb_dob = ["2000-12-28" if i == "00-12-28" else i for i in imdb_dob]
imdb_dob = ["2000-02-22" if i == "00-02-22" else i for i in imdb_dob]
imdb_dob = ["2000-09-05" if i == "00-09-05" else i for i in imdb_dob]
imdb_dob = ["2000-07-10" if i == "00-07-10" else i for i in imdb_dob]
imdb_dob = ["2000-06-23" if i == "00-06-23" else i for i in imdb_dob]
imdb_dob = ["2000-12-10" if i == "00-12-10" else i for i in imdb_dob]
imdb_dob = ["2000-12-17" if i == "00-12-17" else i for i in imdb_dob]
imdb_dob = ["2000-09-20" if i == "00-09-20" else i for i in imdb_dob]
imdb_dob = ["2000-11-29" if i == "00-11-29" else i for i in imdb_dob]
imdb_dob = ["2000-12-17" if i == "00-12-17" else i for i in imdb_dob]
imdb_dob = ["2000-04-12" if i == "00-04-12" else i for i in imdb_dob]
imdb_dob = ["2000-07-22" if i == "00-07-22" else i for i in imdb_dob]
imdb_dob = ["2000-07-10" if i == "00-07-10" else i for i in imdb_dob]
imdb_dob = ["2000-11-06" if i == "00-11-06" else i for i in imdb_dob]
imdb_dob = ["2000-10-02" if i == "00-10-02" else i for i in imdb_dob]
imdb_dob = ["2000-09-09" if i == "00-09-09" else i for i in imdb_dob]
imdb_dob = ["2000-09-07" if i == "00-09-07" else i for i in imdb_dob]
imdb_dob = ["2000-11-13" if i == "00-11-13" else i for i in imdb_dob]
imdb_dob = ["2000-07-27" if i == "00-07-27" else i for i in imdb_dob]
wiki_dob = ["2000-12-22" if i == "00-12-22" else i for i in wiki_dob]
wiki_dob = ["2000-05-21" if i == "00-05-21" else i for i in wiki_dob]
wiki_dob = ["2000-11-18" if i == "00-11-18" else i for i in wiki_dob]
wiki_dob = ["2000-07-31" if i == "00-07-31" else i for i in wiki_dob]
wiki_dob = ["2000-10-20" if i == "00-10-20" else i for i in wiki_dob]
wiki_dob = ["2000-08-19" if i == "00-08-19" else i for i in wiki_dob]
wiki_dob = ["2000-08-07" if i == "00-08-07" else i for i in wiki_dob]
wiki_dob = ["2000-09-08" if i == "00-09-08" else i for i in wiki_dob]
wiki_dob = ["2000-11-19" if i == "00-11-19" else i for i in wiki_dob]
wiki_dob = ["2000-08-05" if i == "00-08-05" else i for i in wiki_dob]
wiki_dob = ["2000-08-27" if i == "00-08-27" else i for i in wiki_dob]
wiki_dob = ["2000-07-08" if i == "00-07-08" else i for i in wiki_dob]
wiki_dob = ["2000-05-05" if i == "00-05-05" else i for i in wiki_dob]
wiki_dob = ["2000-03-15" if i == "00-03-15" else i for i in wiki_dob]
wiki_dob = ["2000-12-29" if i == "00-12-29" else i for i in wiki_dob]
wiki_dob = ["2000-08-21" if i == "00-08-21" else i for i in wiki_dob]
wiki_dob = ["2000-02-16" if i == "00-02-16" else i for i in wiki_dob]
wiki_dob = ["2000-12-10" if i == "00-12-10" else i for i in wiki_dob]
wiki_dob = ["2000-10-17" if i == "00-10-17" else i for i in wiki_dob]
wiki_dob = ["2000-08-08" if i == "00-08-08" else i for i in wiki_dob]
wiki_dob = ["2000-09-02" if i == "00-09-02" else i for i in wiki_dob]
wiki_dob = ["2000-12-28" if i == "00-12-28" else i for i in wiki_dob]
wiki_dob = ["2000-02-22" if i == "00-02-22" else i for i in wiki_dob]
wiki_dob = ["2000-09-05" if i == "00-09-05" else i for i in wiki_dob]
wiki_dob = ["2000-07-10" if i == "00-07-10" else i for i in wiki_dob]
wiki_dob = ["2000-06-23" if i == "00-06-23" else i for i in wiki_dob]
wiki_dob = ["2000-12-10" if i == "00-12-10" else i for i in wiki_dob]
wiki_dob = ["2000-12-17" if i == "00-12-17" else i for i in wiki_dob]
wiki_dob = ["2000-09-20" if i == "00-09-20" else i for i in wiki_dob]
wiki_dob = ["2000-11-29" if i == "00-11-29" else i for i in wiki_dob]
wiki_dob = ["2000-12-17" if i == "00-12-17" else i for i in wiki_dob]
wiki_dob = ["2000-04-12" if i == "00-04-12" else i for i in wiki_dob]
wiki_dob = ["2000-07-22" if i == "00-07-22" else i for i in wiki_dob]
wiki_dob = ["2000-07-10" if i == "00-07-10" else i for i in wiki_dob]
wiki_dob = ["2000-11-06" if i == "00-11-06" else i for i in wiki_dob]
wiki_dob = ["2000-10-02" if i == "00-10-02" else i for i in wiki_dob]
wiki_dob = ["2000-09-09" if i == "00-09-09" else i for i in wiki_dob]
wiki_dob = ["2000-09-07" if i == "00-09-07" else i for i in wiki_dob]
wiki_dob = ["2000-11-13" if i == "00-11-13" else i for i in wiki_dob]
wiki_dob = ["2000-07-27" if i == "00-07-27" else i for i in wiki_dob]

wiki_dob = ["1823-12-01" if i == "1823-12-00" else i for i in wiki_dob]
wiki_dob = ["1963-02-01" if i == "1963-02-00" else i for i in wiki_dob]
wiki_dob = ["1914-02-01" if i == "1914-02-00" else i for i in wiki_dob]
imdb_dob = ["1823-12-01" if i == "1823-12-00" else i for i in imdb_dob]
imdb_dob = ["1963-02-01" if i == "1963-02-00" else i for i in imdb_dob]
imdb_dob = ["1914-02-01" if i == "1914-02-00" else i for i in imdb_dob]

wiki_dob = ["2000-10-07" if i == "0-10-07" else i for i in wiki_dob]
imdb_dob = ["2000-10-07" if i == "0-10-07" else i for i in imdb_dob]
wiki_dob = ["1963-02-01" if i == "1963-02-00" else i for i in wiki_dob]
imdb_dob = ["1963-02-01" if i == "1963-02-00" else i for i in imdb_dob]
wiki_dob = ["1963-02-06" if i == "1963-02-006" else i for i in wiki_dob]

l_in = [s for s in wiki_dob if '63-02-00' in s]
print(l_in)
# ['oneXXXaaa', 'twoXXXbbb']
# Out:
# []

# %%
imdb_age = []
wiki_age = []

for i in range(len(imdb_dob)):
    try:
        d1 = date.datetime.strptime(imdb_dob[i][0:10], '%Y-%m-%d')
        d2 = date.datetime.strptime(str(imdb_photo_taken[i]), '%Y')
        rdelta = relativedelta(d2, d1)#日付に月単位で加減
        diff = rdelta.years
    except Exception as ex:
        print(ex)
        diff = -1
    imdb_age.append(diff)

for i in range(len(wiki_dob)):
    try:
        d1 = date.datetime.strptime(wiki_dob[i][0:10], '%Y-%m-%d')
        d2 = date.datetime.strptime(str(wiki_photo_taken[i]), '%Y')
        rdelta = relativedelta(d2, d1)
        diff = rdelta.years
    except Exception as ex:
        print(ex)
        diff = -1
    wiki_age.append(diff)

final_imdb = np.vstack((imdb_age, imdb_genders, imdb_path, imdb_face_score1, imdb_face_score2)).T
final_wiki = np.vstack((wiki_age, wiki_genders, wiki_path, wiki_face_score1, wiki_face_score2)).T

final_imdb_df = pd.DataFrame(final_imdb)
final_wiki_df = pd.DataFrame(final_wiki)

final_imdb_df.columns = cols
final_wiki_df.columns = cols

meta = pd.concat((final_imdb_df, final_wiki_df))

meta = meta[meta['face_score1'] != '-inf']
meta = meta[meta['face_score2'] == 'nan']

meta = meta.drop(['face_score1', 'face_score2'], axis=1)

meta = meta.sample(frac=1)

meta.to_csv('meta.csv', index=False)

# %%
# Importing dependencies
import pandas as pd
import numpy as np
import cv2
import os
from sklearn.model_selection import train_test_split

# Loading dataset
meta = pd.read_csv('/Users/ShuntaroMiwa/00 python/iiyama/meta.csv')

# Dropping gender column
meta = meta.drop(['gender'], axis=1)

# Filtaring dataset
meta = meta[meta['age'] >= 0]
meta = meta[meta['age'] <= 101]

# Converting into numpy array
meta = meta.values

# Spliting dataset into training and testing set
D_train, D_test = train_test_split(meta, test_size=0.2, random_state=42)

# Making the directory structure
for i in range(102):
    output_dir_train_male = 'dataset/age/train/' + str(i)
    output_dir_train_female = 'dataset/age/train/' + str(i)

    if not os.path.exists(output_dir_train_male):
        os.makedirs(output_dir_train_male)

    if not os.path.exists(output_dir_train_female):
        os.makedirs(output_dir_train_female)

    output_dir_test_male = 'dataset/age/test/' + str(i)
    output_dir_test_female = 'dataset/age/test/' + str(i)

    if not os.path.exists(output_dir_test_male):
        os.makedirs(output_dir_test_male)

    if not os.path.exists(output_dir_test_female):
        os.makedirs(output_dir_test_female)

# Finally making the training and testing set
counter = 0

for image in D_train:
    img = cv2.imread(image[1], 1)
    if img is None:
        print('--('+str(counter)+')Failed--')
        counter += 1
    else:
        img = cv2.resize(img, (128,128))
        cv2.imwrite('dataset/age/train/' + str(image[0]) + '/' + str(counter) + '.jpg', img)
        print('--('+str(counter)+')Processing--')
        counter += 1

counter = 0

for image in D_test:
    img = cv2.imread(image[1], 1)
    if img is None:
        print('--('+str(counter)+')Failed--')
        counter += 1
    else:
        img = cv2.resize(img, (128,128))
        cv2.imwrite('dataset/age/test/' + str(image[0]) +  '/' + str(counter) + '.jpg', img)
        print('--('+str(counter)+')Processing--')
        counter += 1
# Out:
# --(0)Processing--
# --(1)Processing--
# --(2)Processing--
# --(3)Processing--
# --(4)Processing--
# --(5)Processing--
# --(6)Processing--
# --(7)Processing--
# --(8)Processing--
# --(9)Processing--
# --(10)Processing--
# --(11)Processing--
# --(12)Processing--
# --(13)Processing--
# --(14)Processing--
# --(15)Processing--
# --(16)Processing--
# --(17)Processing--
# --(18)Processing--
# --(19)Processing--
# --(20)Processing--
# --(21)Processing--
# --(22)Processing--
# --(23)Processing--
# --(24)Processing--
# --(25)Processing--
# --(26)Processing--
# --(27)Processing--
# --(28)Processing--
# --(29)Processing--
# --(30)Processing--
# --(31)Processing--
# --(32)Processing--
# --(33)Processing--
# --(34)Processing--
# --(35)Processing--
# --(36)Processing--
# --(37)Processing--
# --(38)Processing--
# --(39)Processing--
# --(40)Processing--
# --(41)Processing--
# --(42)Processing--
# --(43)Processing--
# --(44)Processing--
# --(45)Processing--
# --(46)Processing--
# --(47)Processing--
# ...

# %%
# Importing dependencies
import pandas as pd
import numpy as np
import cv2
import os
from sklearn.model_selection import train_test_split

# Loading the data
meta = pd.read_csv('meta.csv')

# Deleting the age column as we dont need it
meta = meta.drop(['age'], axis=1)

# Spliting the dataset into train and test set
D_train, D_test = train_test_split(meta, test_size=0.1, random_state=42)

# The dataset contains more male faces that female faces. This can couse some problems.
# One feature can start dominating on other feature. To solve this I am selecting equal number of male and female faces in the training set
D_train_male = D_train[D_train['gender'] == 'male']
D_train_female = D_train[D_train['gender'] == 'female']

no_male = len(D_train_male)
no_female = len(D_train_female)

if no_male > no_female:
    extra = D_train_male[no_female:]
    D_train_male = D_train_male[0:no_female]

    D_test = pd.concat((D_test, extra))
else:
    extra = D_train_male[no_male:]
    D_train_male = D_train_male[0:no_male]

    D_test = pd.concat((D_test, extra))

D_train = pd.concat((D_train_male, D_train_female))

# Shuffling the dataset
D_train = D_train.sample(frac=1)
D_test = D_test.sample(frac=1)

# Generating folder struture for the data
output_dir_train_male = 'dataset/gender/train/male'
output_dir_train_female = 'dataset/gender/train/female'

if not os.path.exists(output_dir_train_male):
    os.makedirs(output_dir_train_male)

if not os.path.exists(output_dir_train_female):
    os.makedirs(output_dir_train_female)

output_dir_test_male = 'dataset/gender/test/male'
output_dir_test_female = 'dataset/gender/test/female'

if not os.path.exists(output_dir_test_male):
    os.makedirs(output_dir_test_male)

if not os.path.exists(output_dir_test_female):
    os.makedirs(output_dir_test_female)

# Finally processing the image training and testting set
counter = 0

for image in D_train.values:
    img = cv2.imread(image[1], 1)
    if img is None:
        print('--('+str(counter)+')Failed--')
        counter += 1
    else:
        img = cv2.resize(img, (128,128))
        if image[0] == 'male':
            cv2.imwrite('dataset/gender/train/male/' + str(counter) + '.jpg', img)
        else:
            cv2.imwrite('dataset/gender/train/female/' + str(counter) + '.jpg', img)
        print('--('+str(counter)+')Processing--')
        counter += 1

counter = 0

for image in D_test.values:
    img = cv2.imread(image[1], 1)
    if img is None:
        print('--('+str(counter)+')Failed--')
        counter += 1
    else:
        img = cv2.resize(img, (128,128))
        if image[0] == 'male':
            cv2.imwrite('dataset/gender/test/male/' + str(counter) + '.jpg', img)
        else:
            cv2.imwrite('dataset/gender/test/female/' + str(counter) + '.jpg', img)
        print('--('+str(counter)+')Processing--')
        counter += 1
# Out:
# --(0)Processing--
# --(1)Processing--
# --(2)Processing--
# --(3)Processing--
# --(4)Processing--
# --(5)Processing--
# --(6)Processing--
# --(7)Processing--
# --(8)Processing--
# --(9)Processing--
# --(10)Processing--
# --(11)Processing--
# --(12)Processing--
# --(13)Processing--
# --(14)Processing--
# --(15)Processing--
# --(16)Processing--
# --(17)Processing--
# --(18)Processing--
# --(19)Processing--
# --(20)Processing--
# --(21)Processing--
# --(22)Processing--
# --(23)Processing--
# --(24)Processing--
# --(25)Processing--
# --(26)Processing--
# --(27)Processing--
# --(28)Processing--
# --(29)Processing--
# --(30)Processing--
# --(31)Processing--
# --(32)Processing--
# --(33)Processing--
# --(34)Processing--
# --(35)Processing--
# --(36)Processing--
# --(37)Processing--
# --(38)Processing--
# --(39)Processing--
# --(40)Processing--
# --(41)Processing--
# --(42)Processing--
# --(43)Processing--
# --(44)Processing--
# --(45)Processing--
# --(46)Processing--
# --(47)Processing--
# ...

# %% [markdown]
# # ここから

# %%
#https://software-data-mining.com/python%E3%82%92%E7%94%A8%E3%81%84%E3%81%9Frandomforest%E7%94%BB%E5%83%8F%E8%AA%8D%E8%AD%98part-2-%E5%8B%95%E7%89%A9%E7%94%BB%E5%83%8F%E5%88%86%E9%A1%9E%E7%B7%A8%E3%80%90%E3%83%97%E3%83%AD%E3%82%B0/

import numpy as np               
import matplotlib.pyplot as plt  
import cv2
import os
import pandas as pd
import sklearn
import seaborn as sns
from sklearn import tree, ensemble, datasets
from sklearn.ensemble import RandomForestClassifier as RFC
from PIL import Image
from sklearn.model_selection import train_test_split,GridSearchCV
import graphviz          # graphviz.Source を使う

df = pd.read_csv('/Users/ShuntaroMiwa/00 python/iiyama/meta.csv')
df = df.query('age < 11')

path = df['path']

print(path)

#データ設定
counter = 0
features=[]
for f in df['path']:
    img = cv2.imread(f)
    if img is None:
        print('--('+str(counter)+')Failed--')
        counter += 1
    else:
        features2 = np.array([cv2.cvtColor(cv2.resize(cv2.imread(f), (64, 64), cv2.INTER_CUBIC), cv2.COLOR_BGR2RGB)])
        features.append(features2)
        print('--('+str(counter)+')Processing--')
        counter += 1

#print(x_train)
features = np.array(features)

print(features.shape)
#print(featureｓ[0][0])

# print(x_data.shape)
# print(y_data.shape)

# 画像データをベクトルに変換
# print(features.shape)
 
x_data = features.reshape(features.shape[0], features.shape[2]*features.shape[3]*features.shape[4]).astype('float32') / 255.0
#x_data = features.reshape(features.shape[0], features.shape[1]*features.shape[2]*features.shape[3]).astype('float32') / 255.0
y_data = np.array(df['gender'].astype(int))
 
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2)
fx_train, fx_test, fy_train, fy_test = train_test_split(features, y_data, test_size=0.2)
# Out:
# 0       /Users/ShuntaroMiwa/00 python/iiyama/imdb_crop...
# 1       /Users/ShuntaroMiwa/00 python/iiyama/imdb_crop...
# 2       /Users/ShuntaroMiwa/00 python/iiyama/imdb_crop...
# 3       /Users/ShuntaroMiwa/00 python/iiyama/imdb_crop...
# 4       /Users/ShuntaroMiwa/00 python/iiyama/imdb_crop...
#                               ...
# 1510    /Users/ShuntaroMiwa/00 python/iiyama/imdb_crop...
# 1511    /Users/ShuntaroMiwa/00 python/iiyama/imdb_crop...
# 1512    /Users/ShuntaroMiwa/00 python/iiyama/imdb_crop...
# 1513    /Users/ShuntaroMiwa/00 python/iiyama/imdb_crop...
# 1514    /Users/ShuntaroMiwa/00 python/iiyama/imdb_crop...
# Name: path, Length: 1515, dtype: object
# --(0)Processing--
# --(1)Processing--
# --(2)Processing--
# --(3)Processing--
# --(4)Processing--
# --(5)Processing--
# --(6)Processing--
# --(7)Processing--
# --(8)Processing--
# --(9)Processing--
# --(10)Processing--
# --(11)Processing--
# --(12)Processing--
# --(13)Processing--
# --(14)Processing--
# ...

# %% [markdown]
# # 決定木

# %%
dt = tree.DecisionTreeClassifier() 
dt.set_params(max_depth=4)            # 木の深さの最大値を設定（→枝刈り）
dt.fit(x_data, y_data)              # フィッティング
1-dt.score(x_data, y_data)           # トレーニング誤差
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3c655ef07b59> in <module>
#       1 dt = tree.DecisionTreeClassifier()
#       2 dt.set_params(max_depth=4)            # 木の深さの最大値を設定（→枝刈り）
# ----> 3 dt.fit(fx_data, fy_data)              # フィッティング
#       4 1-dt.score(x_data, y_data)           # トレーニング誤差
#
# NameError: name 'fx_data' is not defined

# %%
# graphvizで決定木を描画
graph = graphviz.Source(tree.export_graphviz(dt,out_file=None))
graph.render("DTplot",view="TRUE")     # 図をファイルに出力
# Out:
# 'DTplot.pdf'

# %% [markdown]
# # ランダムフォレスト

# %%
# x, y    = xa[:100,:], ya[:100]          # トレーニングデータ
# tx, ty = xa[100:,:], ya[100:]          # テストデータ
# ランダムフォレスト：木の数 10
rf = ensemble.RandomForestClassifier()
# rf.fit(x_train,y_train)
# 1-rf.score(x_test,y_test)    # テスト誤差

T = 100
rf_tr_err = np.zeros((T,))            
rf_te_err = np.zeros((T,)) 
for i in range(1,100): 
    rf.set_params(n_estimators=i)
    rf.fit(x_train,y_train)
    score = rf.score(x_train,y_train)
    rf_tr_err[i] = 1-score                     # トレーニング誤差
    score2 = rf.score(x_test,y_test)
    rf_te_err[i] = 1-score2                    # テスト誤差
    
plt.xlabel('round: t')
plt.ylabel('error')
plt.plot(rf_tr_err,label='training error',linestyle='dashed',lw=3)
plt.plot(rf_te_err,label='test error',    linestyle='solid', lw=3)
plt.legend()
plt.show()

# %%
import seaborn as sns
rf_imp = np.reshape(rf.feature_importances_,(64,64,3))
#print(rf_imp.shape)
rf_imp_r = rf_imp[:, :, 0]
rf_imp_g = rf_imp[:, :, 1]
rf_imp_b = rf_imp[:, :, 2]
sns.heatmap(rf_imp_r ,cmap="terrain",square=True)
sns.heatmap(rf_imp_g ,cmap="terrain",square=True)
sns.heatmap(rf_imp_b,cmap="terrain",square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 決定木

# %%
T = 20
dt = tree.DecisionTreeClassifier()      #  決定木
# dt.fit(x_train,y_train)
# 1-dt.score(x_test,y_test)    # テスト誤差

dt_tr_err = np.zeros((T,))
dt_te_err = np.zeros((T,))
for i in range(1,20): 
    dt.set_params(max_depth=i)
    dt.fit(x_train,y_train)
    score = dt.score(x_train,y_train)
    dt_tr_err[i] = 1-score                     # トレーニング誤差
    score2= dt.score(x_test,y_test)
    dt_te_err[i] = 1-score2# テスト誤差
    
# dt_tr_err = np.zeros((T,))            
# for i in range(1,21): 
#     dt.set_params(max_depth=i)
#     dt.fit(x_test,y_test)
#     score2= dt.score(x_test,y_test)
#     dt_te_err[i] = 1-score2# テスト誤差
    
plt.xlabel('depth')
plt.ylabel('error')
plt.plot(dt_tr_err,label='training error',linestyle='dashed',lw=3)
plt.plot(dt_te_err,label='test error',    linestyle='solid', lw=3)
plt.legend()
plt.show()

# %% [markdown]
# # バギング

# %%
ba = ensemble.BaggingClassifier()  # バギング(B=10)

T=20
ba_tr_err = np.zeros((T,))            
ba_te_err = np.zeros((T,)) 
for i in range(1,20): 
    ba.set_params(n_estimators=i)
    ba.fit(x_train,y_train)
    score = ba.score(x_train,y_train)
    ba_tr_err[i] = 1-score                     # トレーニング誤差
    score2 = ba.score(x_test,y_test)
    ba_te_err[i] = 1-score2                    # テスト誤差
    
plt.xlabel('round: t')
plt.ylabel('error')
plt.plot(ba_tr_err,label='training error',linestyle='dashed',lw=3)
plt.plot(ba_te_err,label='test error',    linestyle='solid', lw=3)
plt.legend()
plt.show()

# plt.xlabel('round: t')
# plt.ylabel('error')
# plt.plot(ada_tr_err,label='training error',linestyle='dashed',lw=3)
# plt.plot(ada_te_err,label='test error',    linestyle='solid', lw=3)
# plt.legend()
# plt.show()
# # テスト誤差

# plt.xlabel('round: t')
# plt.ylabel('error')
# plt.plot(ada_tr_err,label='training error',linestyle='dashed',lw=3)
# plt.plot(ada_te_err,label='test error',    linestyle='solid', lw=3)
# plt.legend()
# plt.show()

# %% [markdown]
# # ブースティング

# %%
T = 100                                    # ブースティング：ラウンド数
bl = tree.DecisionTreeClassifier(max_depth=1)               # 決定株
# 決定株でアダブーストを実行
ab = ensemble.AdaBoostClassifier(base_estimator=bl, n_estimators=T)
ab.fit(x_train,y_train)                                # フィッティング
# 各ラウンドの誤差
ada_tr_err = np.zeros((T,))            
for i, score in enumerate(ab.staged_score(x_train,y_train)): 
    ada_tr_err[i] = 1-score                     # トレーニング誤差
ada_te_err = np.zeros((T,))            
for i, score in enumerate(ab.staged_score(x_test,y_test)): 
    ada_te_err[i] = 1-score                     # テスト誤差

# %%
plt.xlabel('round: t')
plt.ylabel('error')
plt.plot(ada_tr_err,label='training error',linestyle='dashed',lw=3)
plt.plot(ada_te_err,label='test error',    linestyle='solid', lw=3)
plt.legend()
plt.show()

# %% [markdown]
# # XGboost

# %%
conda install -c anaconda py-xgboost
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/DataScience_visual
#
#   added / updated specs:
#     - py-xgboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libxgboost-0.90            |       hb1e8313_1         2.3 MB  anaconda
#     py-xgboost-0.90            |   py37hb1e8313_1          76 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         2.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   _py-xgboost-mutex  anaconda/osx-64::_py-xgboost-mutex-2.0-cpu_0
#   libxgboost         anaconda/osx-64::libxgboost-0.90-hb1e8313_1
#   py-xgboost         anaconda/osx-64::py-xgboost-0.90-py37hb1e8313_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
# ...

# %%
import xgboost as xgb          # xgboostを使う

T = 100                     # ラウンド数 100
xg = xgb.XGBClassifier()

# xg.fit(x,y)                    # フィッティング
# 1-xg.score(tx,ty)              # テスト誤差

xg_tr_err = np.zeros((T,))            
xg_te_err = np.zeros((T,)) 
for i in range(1,100): 
    xg.set_params(n_estimators=i, max_depth=1, objective='binary:logistic')
    xg.fit(x_train,y_train)
    score = xg.score(x_train,y_train)
    xg_tr_err[i] = 1-score                     # トレーニング誤差
    score2 = xg.score(x_test,y_test)
    xg_te_err[i] = 1-score2                    # テスト誤差
    
plt.xlabel('round: t')
plt.ylabel('error')
plt.plot(xg_tr_err,label='training error',linestyle='dashed',lw=3)
plt.plot(xg_te_err,label='test error',    linestyle='solid', lw=3)
plt.legend()
plt.show()

# %% [markdown]
# # ニューラルネット

# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.utils import np_utils #分類問題のワンホット表現を作る
from keras.utils.vis_utils import model_to_dot
# Out:
# Using TensorFlow backend.

# %%
b_size = 200#バッチのサイズ
n_classes = 2#教師データの種類
n_hidden = 200
n_epoch = 5#５回学習

img_size = 64

y_data_nn = np_utils.to_categorical(np.array(df['gender'].astype(int)))
 
y_train_nn, y_test_nn = train_test_split(y_data_nn, test_size=0.2)

# %%
# ##手書き文字の一部が表示
# def draw_digit3(data, n, numbers_size, title=None):
#     plt.subplot(numbers_size, numbers_size, n)
#     Z = data.reshape(img_size, img_size)
#     Z = Z[::-1,:]
#     plt.xlim(0, img_size-1)
#     plt.ylim(0, img_size-1)
#     plt.pcolor(Z)
#     if title is not None:
#         plt.title(title, size=9)
#     plt.gray()
#     plt.tick_params(labelbottom=False)
#     plt.tick_params(labelleft=False)
# plt.style.use('fivethirtyeight')#カラー画像の表示の時に使う
# numbers_size = 4#4*4の画像を表示
# plt.figure(figsize=(5,5))
# for cnt,idx in enumerate(np.random.permutation(len(X_train))[:numbers_size**2]):
#     draw_digit3(X_train[idx], cnt+1, numbers_size)
# plt.show()

# %%
from IPython.display import SVG

model = Sequential()#構造ニューラルネットを初期化

model.add(Dense(n_hidden, input_dim=img_size*img_size))#結合荷重を入れる（中間層、784行列を入力に使いますよ）
model.add(Activation('relu'))#reLU関数

model.add(Dense(n_classes))#10クラス分類の出力、サイズはkerasが把握しているので入力不要
model.add(Activation('sigmoid'))#分類はsoftmaxが定石,2値はsigmoid

model.summary()#モデルのサマリが出てくる

SVG(model_to_dot(model, show_shapes=True, show_layer_names=False).create(prog='dot', format='svg'))#モデルの出力
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 200)               819400
# _________________________________________________________________
# activation_3 (Activation)    (None, 200)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 402
# _________________________________________________________________
# activation_4 (Activation)    (None, 2)                 0
# ...
# Total params: 819,802
# Trainable params: 819,802
# Non-trainable params: 0
# _________________________________________________________________
